# %%
# !pip install pandas openpyxl
# Out:
# ...
#
#    ---------------------------------------- 0/2 [et-xmlfile]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings as wr
wr.filterwarnings('ignore')

# %%
df=pd.read_excel("Credit_Card.xlsx")

# %%
df.rename(columns={'current_year': 'Current_Year'}, inplace=True)

# %%
df.head(3)
# Out:
#    Client_Num Card_Category  Annual_Fees  Activation_30_Days  \
# 0   708082083          Blue          200                   0
# 1   708083283          Blue          445                   1
# 2   708084558          Blue          140                   0
#
#    Customer_Acq_Cost Week_Start_Date Week_Num Qtr  Current_Year  Credit_Limit  \
# 0                 87      2023-01-01   Week-1  Q1          2023        3544.0
# 1                108      2023-01-01   Week-1  Q1          2023        3421.0
# 2                106      2023-01-01   Week-1  Q1          2023        8258.0
#
#    Total_Revolving_Bal  Total_Trans_Amt  Total_Trans_Vol  \
# 0                 1661            15149              111
# 1                 2517              992               21
# 2                 1771             1447               23
#
#    Avg_Utilization_Ratio Use_Chip       Exp_Type  Interest_Earned  \
# 0                  0.469    Chip          Travel          4393.21
# ...

# %%
df.tail(5)
# Out:
#        Client_Num Card_Category  Annual_Fees  Activation_30_Days  \
# 10288   964474458          Blue          100                   0
# 10289   962482385        Silver          100                   1
# 10290   919695363          Blue          475                   1
# 10291   931822111          Blue          275                   0
# 10292   925168075          Blue          245                   1
#
#        Customer_Acq_Cost Week_Start_Date Week_Num Qtr  Current_Year  \
# 10288                 72      2023-12-31  Week-53  Q4          2023
# 10289                150      2023-12-31  Week-53  Q4          2023
# 10290                 99      2023-12-31  Week-53  Q4          2023
# 10291                 99      2023-12-31  Week-53  Q4          2023
# 10292                 74      2023-12-31  Week-53  Q4          2023
#
#        Credit_Limit  Total_Revolving_Bal  Total_Trans_Amt  Total_Trans_Vol  \
# 10288        1438.3                    0             4928               84
# ...

# %%
df.shape
# Out:
# (10293, 18)

# %%
df.size
# Out:
# 185274

# %%
df.columns
# Out:
# Index(['Client_Num', 'Card_Category', 'Annual_Fees', 'Activation_30_Days',
#        'Customer_Acq_Cost', 'Week_Start_Date', 'Week_Num', 'Qtr',
#        'Current_Year', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Total_Trans_Amt', 'Total_Trans_Vol', 'Avg_Utilization_Ratio',
#        'Use_Chip', 'Exp_Type', 'Interest_Earned', 'Delinquent_Acc'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Client_Num                        int64
# Card_Category                    object
# Annual_Fees                       int64
# Activation_30_Days                int64
# Customer_Acq_Cost                 int64
# Week_Start_Date          datetime64[ns]
# Week_Num                         object
# Qtr                              object
# Current_Year                      int64
# Credit_Limit                    float64
# Total_Revolving_Bal               int64
# Total_Trans_Amt                   int64
# Total_Trans_Vol                   int64
# Avg_Utilization_Ratio           float64
# Use_Chip                         object
# Exp_Type                         object
# Interest_Earned                 float64
# Delinquent_Acc                    int64
# dtype: object

# %%
df.info
# Out:
# <bound method DataFrame.info of        Client_Num Card_Category  Annual_Fees  Activation_30_Days  \
# 0       708082083          Blue          200                   0
# 1       708083283          Blue          445                   1
# 2       708084558          Blue          140                   0
# 3       708085458          Blue          250                   1
# 4       708086958          Blue          320                   1
# ...           ...           ...          ...                 ...
# 10288   964474458          Blue          100                   0
# 10289   962482385        Silver          100                   1
# 10290   919695363          Blue          475                   1
# 10291   931822111          Blue          275                   0
# 10292   925168075          Blue          245                   1
#
#        Customer_Acq_Cost Week_Start_Date Week_Num Qtr  Current_Year  \
# 0                     87      2023-01-01   Week-1  Q1          2023
# ...

# %%
df.isnull()
# Out:
#        Client_Num  Card_Category  Annual_Fees  Activation_30_Days  \
# 0           False          False        False               False
# 1           False          False        False               False
# 2           False          False        False               False
# 3           False          False        False               False
# 4           False          False        False               False
# ...           ...            ...          ...                 ...
# 10288       False          False        False               False
# 10289       False          False        False               False
# 10290       False          False        False               False
# 10291       False          False        False               False
# 10292       False          False        False               False
#
#        Customer_Acq_Cost  Week_Start_Date  Week_Num    Qtr  Current_Year  \
# 0                  False            False     False  False         False
# ...

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10288    False
# 10289    False
# 10290    False
# 10291    False
# 10292    False
# Length: 10293, dtype: bool

# %%
df.drop_duplicates()
# Out:
#        Client_Num Card_Category  Annual_Fees  Activation_30_Days  \
# 0       708082083          Blue          200                   0
# 1       708083283          Blue          445                   1
# 2       708084558          Blue          140                   0
# 3       708085458          Blue          250                   1
# 4       708086958          Blue          320                   1
# ...           ...           ...          ...                 ...
# 10288   964474458          Blue          100                   0
# 10289   962482385        Silver          100                   1
# 10290   919695363          Blue          475                   1
# 10291   931822111          Blue          275                   0
# 10292   925168075          Blue          245                   1
#
#        Customer_Acq_Cost Week_Start_Date Week_Num Qtr  Current_Year  \
# 0                     87      2023-01-01   Week-1  Q1          2023
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        Client_Num Card_Category  Annual_Fees  Activation_30_Days  \
# 0       708082083          Blue          200                   0
# 1       708083283          Blue          445                   1
# 2       708084558          Blue          140                   0
# 3       708085458          Blue          250                   1
# 4       708086958          Blue          320                   1
# ...           ...           ...          ...                 ...
# 10288   964474458          Blue          100                   0
# 10289   962482385        Silver          100                   1
# 10290   919695363          Blue          475                   1
# 10291   931822111          Blue          275                   0
# 10292   925168075          Blue          245                   1
#
#        Customer_Acq_Cost Week_Start_Date Week_Num Qtr  Current_Year  \
# 0                     87      2023-01-01   Week-1  Q1          2023
# ...

# %%
df['Credit_Limit'].round(0)
# Out:
# 0         3544.0
# 1         3421.0
# 2         8258.0
# 3         1438.0
# 4         3128.0
#           ...
# 10288     1438.0
# 10289    34516.0
# 10290     3807.0
# 10291    11548.0
# 10292    20769.0
# Name: Credit_Limit, Length: 10293, dtype: float64

# %%
df['Credit_Limit'].max()
# Out:
# np.float64(34516.0)

# %%
df['Credit_Limit'].min()
# Out:
# np.float64(1438.3)

# %%
df['Credit_Limit'].mean()
# Out:
# np.float64(8642.414845040319)

# %%
df['Credit_Limit'].median()
# Out:
# np.float64(4555.0)

# %%
df['Credit_Limit'].var()
# Out:
# np.float64(82759814.3398282)

# %%
df.isnull().sum()
# Out:
# Client_Num               0
# Card_Category            0
# Annual_Fees              0
# Activation_30_Days       0
# Customer_Acq_Cost        0
# Week_Start_Date          0
# Week_Num                 0
# Qtr                      0
# Current_Year             0
# Credit_Limit             0
# Total_Revolving_Bal      0
# Total_Trans_Amt          0
# Total_Trans_Vol          0
# Avg_Utilization_Ratio    0
# Use_Chip                 0
# Exp_Type                 0
# Interest_Earned          0
# Delinquent_Acc           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Card_Category'].unique()
# Out:
# array(['Blue', 'Platinum', 'Silver', 'Gold'], dtype=object)

# %%
df['Use_Chip'].nunique()
# Out:
# 3

# %%
df['Use_Chip'].unique()
# Out:
# array(['Chip ', 'Swipe ', 'Online '], dtype=object)

# %%
df['Card_Category'].value_counts()
# Out:
# Card_Category
# Blue        9384
# Silver       649
# Gold         193
# Platinum      67
# Name: count, dtype: int64

# %%
df.groupby('Card_Category').max()
# Out:
#                Client_Num  Annual_Fees  Activation_30_Days  Customer_Acq_Cost  \
# Card_Category
# Blue            968936158          500                   1                172
# Gold            966406115          495                   1                164
# Platinum        823848183          490                   1                160
# Silver          967367842          495                   1                170
#
#               Week_Start_Date Week_Num Qtr  Current_Year  Credit_Limit  \
# Card_Category
# Blue               2023-12-31   Week-9  Q4          2023       34516.0
# Gold               2023-12-31   Week-9  Q4          2023       34516.0
# Platinum           2023-12-24   Week-9  Q4          2023       34516.0
# Silver             2023-12-31   Week-9  Q4          2023       34516.0
#
#                Total_Revolving_Bal  Total_Trans_Amt  Total_Trans_Vol  \
# Card_Category
# Blue                          2517            79463              124
# ...

# %%
df.groupby('Card_Category').min()
# Out:
#                Client_Num  Annual_Fees  Activation_30_Days  Customer_Acq_Cost  \
# Card_Category
# Blue            708082083           95                   0                 40
# Gold            708226833           95                   0                 40
# Platinum        708103608           95                   0                 46
# Silver          708123033           95                   0                 40
#
#               Week_Start_Date Week_Num Qtr  Current_Year  Credit_Limit  \
# Card_Category
# Blue               2023-01-01   Week-1  Q1          2023        1438.3
# Gold               2023-01-01   Week-1  Q1          2023        2754.0
# Platinum           2023-01-01   Week-1  Q1          2023        3638.0
# Silver             2023-01-01   Week-1  Q1          2023        2405.0
#
#                Total_Revolving_Bal  Total_Trans_Amt  Total_Trans_Vol  \
# Card_Category
# Blue                             0              510               10
# ...

# %%
pd.crosstab(df['Card_Category'], df['Activation_30_Days'])  #to show the relationship between 2 categorial table
# Out:
# Activation_30_Days     0     1
# Card_Category
# Blue                4018  5366
# Gold                  86   107
# Platinum              28    39
# Silver               247   402

# %%
# Brainstrom about how u can use here { df.corr() } to find correlation

# %%
# see only blue card 
df.loc[df['Card_Category']=='Blue']
# Out:
#        Client_Num Card_Category  Annual_Fees  Activation_30_Days  \
# 0       708082083          Blue          200                   0
# 1       708083283          Blue          445                   1
# 2       708084558          Blue          140                   0
# 3       708085458          Blue          250                   1
# 4       708086958          Blue          320                   1
# ...           ...           ...          ...                 ...
# 10287   956303078          Blue          410                   0
# 10288   964474458          Blue          100                   0
# 10290   919695363          Blue          475                   1
# 10291   931822111          Blue          275                   0
# 10292   925168075          Blue          245                   1
#
#        Customer_Acq_Cost Week_Start_Date Week_Num Qtr  Current_Year  \
# 0                     87      2023-01-01   Week-1  Q1          2023
# ...

# %%
df_plat=df.loc[df['Card_Category']=='Platinum']
df_plat
# Out:
#       Client_Num Card_Category  Annual_Fees  Activation_30_Days  \
# 9      708103608      Platinum           95                   1
# 37     708163758      Platinum          470                   0
# 262    708654933      Platinum          480                   0
# 382    708873183      Platinum          380                   0
# 420    708942408      Platinum          345                   0
# ...          ...           ...          ...                 ...
# 8594   789074358      Platinum           95                   0
# 8755   789539058      Platinum          440                   1
# 8969   794494308      Platinum          425                   0
# 9160   801036033      Platinum          300                   1
# 9991   823848183      Platinum          350                   1
#
#       Customer_Acq_Cost Week_Start_Date Week_Num Qtr  Current_Year  \
# 9                    80      2023-01-01   Week-1  Q1          2023
# ...

# %%
df.head()
# Out:
#    Client_Num Card_Category  Annual_Fees  Activation_30_Days  \
# 0   708082083          Blue          200                   0
# 1   708083283          Blue          445                   1
# 2   708084558          Blue          140                   0
# 3   708085458          Blue          250                   1
# 4   708086958          Blue          320                   1
#
#    Customer_Acq_Cost Week_Start_Date Week_Num Qtr  Current_Year  Credit_Limit  \
# 0                 87      2023-01-01   Week-1  Q1          2023        3544.0
# 1                108      2023-01-01   Week-1  Q1          2023        3421.0
# 2                106      2023-01-01   Week-1  Q1          2023        8258.0
# 3                150      2023-01-01   Week-1  Q1          2023        1438.3
# 4                106      2023-01-01   Week-1  Q1          2023        3128.0
#
#    Total_Revolving_Bal  Total_Trans_Amt  Total_Trans_Vol  \
# 0                 1661            15149              111
# ...

# %% [markdown]
# 1. Categorical Data   ---> Q. Find customer with great profit for company

# %% [markdown]
# A. Countplot

# %%
sns.countplot(data=df, x='Card_Category')
# Out:
# <Axes: xlabel='Card_Category', ylabel='count'>

# %%
df['Card_Category'].dtype.name
# Out:
# 'object'

# %%
sns.countplot(df['Use_Chip'])
# Out:
# <Axes: xlabel='count', ylabel='Use_Chip'>

# %%
sns.countplot(df['Exp_Type'])
# Out:
# <Axes: xlabel='count', ylabel='Exp_Type'>

# %% [markdown]
# B.PieChart

# %%
# df['Exp Type'].value_counts().plot(kind='bar')
df['Exp_Type'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['Exp_Type'].value_counts().plot(kind='pie', autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# 2. numerical DATA
# A HISTOGRAM

# %%
plt.hist(df['Exp_Type'],bins=15)
# Out:
# (array([ 717.,    0.,    0., 2030.,    0.,    0., 3014.,    0.,    0.,
#         1533.,    0.,    0., 1789.,    0., 1210.]),
#  array([0.        , 0.33333333, 0.66666667, 1.        , 1.33333333,
#         1.66666667, 2.        , 2.33333333, 2.66666667, 3.        ,
#         3.33333333, 3.66666667, 4.        , 4.33333333, 4.66666667,
#         5.        ]),
#  <BarContainer object of 15 artists>)

# %% [markdown]
# B. DISPLOT

# %%
sns.displot(df['Exp_Type'])

# %% [markdown]
# B ANOTHER VARIENT {DISTPLOT}  ---> says about probility

# %%
sns.distplot(df['Activation_30_Days'])
# Out:
# <Axes: xlabel='Activation_30_Days', ylabel='Density'>

# %% [markdown]
# C. Bloxpot ---> 5 number summery deta hai

# %%
#sns.boxplot(df['Interest_Earned'])
sns.boxplot(df['Total_Trans_Amt'])
# Out:
# <Axes: ylabel='Total_Trans_Amt'>

# %%
df['Interest_Earned'].skew()
# Out:
# np.float64(2.526194050364101)

# %%
df['Total_Trans_Amt'].skew()
# Out:
# np.float64(2.858162191720747)

# %%
df['Activation_30_Days']  #to see the colm
# Out:
# 0        0
# 1        1
# 2        0
# 3        1
# 4        1
#         ..
# 10288    0
# 10289    1
# 10290    1
# 10291    0
# 10292    1
# Name: Activation_30_Days, Length: 10293, dtype: int64

# %%
df['Activation_30_Days'].value_counts(normalize=True)
# Out:
# Activation_30_Days
# 1    0.574565
# 0    0.425435
# Name: proportion, dtype: float64

# %% [markdown]
#     <----OR---->

# %%
r=(df['Activation_30_Days']).value_counts(normalize=True)
rate_of_x=r[1]*100
print(f"Activation Rate is","{:.2f}".format(rate_of_x),"%")
# Out:
# Activation Rate is 57.46 %

# %%
r=(df['Delinquent_Acc']).value_counts(normalize=True)
rate_of_x = r[1]*100
print(f"Delinquent Account Rate is","{:.2f}".format(rate_of_x),"%")
# Out:
# Delinquent Account Rate is 6.06 %

# %%
df['Total_Trans_Amt'].sum()
# Out:
# np.int64(45533021)
